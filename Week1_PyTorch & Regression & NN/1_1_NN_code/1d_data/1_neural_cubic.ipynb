# %% [markdown]
# # Neural Network with Cubic Data
# - y = x^3 -3x^2 -9x -1
# - 5 hidden layers

# %% [markdown]
# ## 1.Import Required Libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.autograd import Variable
from visdom import Visdom
viz = Visdom()

# %% [markdown]
# ## 2. Data Generation

# %%
num_data = 1000
num_epoch = 5000

x = init.uniform(torch.Tensor(num_data,1),-10,10)
y = (x**3) - 3*(x**2) - 9*x - 1

noise = init.normal(torch.FloatTensor(num_data,1),std=0.5)

y_noise = y + noise

# %%
# visualize data

input_data = torch.cat([x,y_noise],1)

win=viz.scatter(
    X = input_data,
    opts=dict(
        xtickmin=-10,
        xtickmax=10,
        xtickstep=1,
        ytickmin=0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, num_data),
        markersize=5,
    ),
)

viz.updateTrace(
    X = x,
    Y = y,
    win=win,
)
# Out:
# 'window_3619e98e72b740'

# %% [markdown]
# ## 3. Model & Optimizer

# %%
# fully connected model with 5 hidden layer

model = nn.Sequential(
            nn.Linear(1,20),
            nn.ReLU(),
            nn.Linear(20,10),
            nn.ReLU(),
            nn.Linear(10,5),
            nn.ReLU(),
            nn.Linear(5,1),
        )#.cuda()

loss_func = nn.L1Loss()
optimizer = optim.SGD(model.parameters(),lr=0.0005)

# %% [markdown]
# ## 4. Train

# %%
loss_arr =[]
label = Variable(y_noise)

for i in range(num_epoch):
    output = model(Variable(x))
    optimizer.zero_grad()

    loss = loss_func(output,label)
    loss.backward()
    optimizer.step()
    
    if i % 100 ==0:
        print(loss)
        
    loss_arr.append(loss.data.numpy()[0])
# Out:
# Variable containing:
#  218.8412
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  218.6863
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  218.5217
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  218.2932
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  217.9128
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  217.2137
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  215.7362
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  211.9659
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  199.2951
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  156.2556
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  139.3981
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  137.9908
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  136.5954
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  135.1569
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  133.6682
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  132.0902
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  130.3800
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  128.4795
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  126.3006
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  123.7014
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  120.5012
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  116.4432
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  111.1243
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  104.1346
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  96.3870
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  89.0554
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  82.2425
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  76.9388
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  73.5205
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  73.0729
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  72.5773
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  71.6809
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  70.8528
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  72.0023
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  69.5703
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  70.2332
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  71.0763
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  68.9336
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  69.9503
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  68.0908
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  69.5081
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.8637
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  69.4473
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  68.2859
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.5270
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.9440
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.7802
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.9382
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.8031
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  67.3150
# [torch.FloatTensor of size 1]

# %%
param_list = list(model.parameters())
print(param_list)
# Out:
# [Parameter containing:
#  0.4546
#  0.7691
# -0.9579
# -0.9305
# -0.6671
# -0.2166
#  0.5000
# -0.5364
#  0.9171
# -0.6660
# -0.5625
#  0.2971
# -0.2524
# -0.4634
#  0.4555
#  0.0231
# -0.4552
# -0.3749
#  0.6118
# -0.4300
# [torch.FloatTensor of size 20x1]
# , Parameter containing:
#  0.2350
#  0.1266
# -1.2664
# -1.9753
#  0.0711
# -2.2380e-01  7.4107e-03  1.3093e-01 -7.9667e-02 -2.0219e-01  1.5794e-02
# -2.1760e-02  2.0599e-02  2.9011e-01 -1.3895e-02 -2.2049e-01  2.5261e-02
# -3.2017e-02  3.2566e-01 -3.7235e-01  8.8604e-02  1.1867e-01 -1.4343e-01
# -2.4287e-01 -1.0737e-01 -5.4330e-02  1.9604e-02  1.9724e-01 -1.3139e-02
# -9.9641e-02  1.0816e-01  8.0104e-02 -1.7308e-01 -1.2061e-01 -2.0822e-01
#  3.7479e-02  1.7884e-01 -1.2479e-01  1.2064e-01 -9.1709e-02 -1.7613e-01
#
# Columns 18 to 19
# -2.7968e-02  9.4214e-01
#  2.7078e-02  9.2698e-02
# -1.6546e-01  5.2439e-01
#  2.5685e-02  6.9850e-01
# -1.2781e-01  1.5138e-01
#  1.9860e-02  4.5703e-02
# -1.5469e-01  3.9081e-01
# -4.8868e-05  2.7429e-04
#  4.6168e-02  8.2961e-02
# -7.5886e-02  2.0282e-02
# [torch.FloatTensor of size 10x20]
# , Parameter containing:
# -0.2103
#  0.0940
# -0.8968
# -0.6931
# -0.2170
# -0.2233
# -0.0398
#  0.1964
# -0.2186
#  0.1187
# [torch.FloatTensor of size 10]
# , Parameter containing:
#  2.5342  0.1617  1.2801  1.5576  0.0232 -0.2488  0.6981  0.2929  0.1679 -0.2593
#  0.0716 -0.2301 -0.0071 -0.0831 -0.0799 -0.1055 -0.0798 -0.1474  0.1628  0.1401
#  1.8383  0.2283  1.3128  0.9520 -0.2504 -0.3309  0.4805 -0.0508 -0.0938 -0.1864
#  2.3997  0.3013  1.1391  1.2801 -0.1622 -0.3787  0.3810  0.3742 -0.1232 -0.0999
#  0.1940 -0.1671  0.1741  0.2310  0.0674  0.0001  0.0865 -0.0362 -0.2766  0.2015
# [torch.FloatTensor of size 5x10]
# , Parameter containing:
# -0.1921
# -0.2834
# -0.0307
# -0.0452
# -0.0365
# [torch.FloatTensor of size 5]
# , Parameter containing:
# -3.3408 -0.1210 -2.4998 -2.9839 -0.3186
# [torch.FloatTensor of size 1x5]
# , Parameter containing:
#  0.7244
# [torch.FloatTensor of size 1]
# ]

# %% [markdown]
# ## 5. Visualize Trained Output

# %%
win2=viz.scatter(
    X = input_data,
    opts=dict(
        xtickmin=-10,
        xtickmax=10,
        xtickstep=1,
        ytickmin=0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, num_data),
        markersize=5,
    ),
)

viz.updateTrace(
    X = x,
    Y = output.data,
    win = win2,
)
# Out:
# 'window_3619e9907a1a72'

# %% [markdown]
# ## 6. Visualize Loss Graph

# %%
x = np.reshape([i for i in range(num_epoch)],newshape=[num_epoch,1])
loss_data = np.reshape(loss_arr,newshape=[num_epoch,1])

win3=viz.line(
    X = x,
    Y = loss_data, 
)
